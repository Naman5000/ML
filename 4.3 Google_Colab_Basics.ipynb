# %% [markdown]
# # **System Specifications**

# %%
! cat /proc/cpuinfo
# This command is used to display the CPU information, since it is a Linux Commmand, we start with "!".
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
! cat /proc/meminfo
# This command is used to display the Memory information.
# Out:
# MemTotal:       13290460 kB
# MemFree:         8963916 kB
# MemAvailable:   12009408 kB
# Buffers:          114204 kB
# Cached:          3087540 kB
# SwapCached:            0 kB
# Active:           796140 kB
# Inactive:        3180740 kB
# Active(anon):       1248 kB
# Inactive(anon):   775516 kB
# Active(file):     794892 kB
# Inactive(file):  2405224 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1880 kB
# Writeback:             0 kB
# AnonPages:        775172 kB
# Mapped:           329924 kB
# Shmem:              1620 kB
# KReclaimable:     170780 kB
# Slab:             214016 kB
# SReclaimable:     170780 kB
# SUnreclaim:        43236 kB
# KernelStack:        6080 kB
# PageTables:        12516 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    2984092 kB
# ...

# %% [markdown]
# # **Installing Libraries**

# %%
# !pip install pandas
# This is a sample command to install a library, however most of the libraries are already pre-installed in Colab.
# Hence the execution of this commands shows "Requirement Already Satisfied"

# %%
import pandas as pd
# Importing Library.
# Libaries in Python are a set of pre-defined functions and we import these libraries to use these pre-defined functions.

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
# Here df is the name of our dataframe.
# read_csv is the function that will load the file to the pd (Pandas) library.

# %%
df.head()
# Commnad to display first 5 rows of the dataset.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
